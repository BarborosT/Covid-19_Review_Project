# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import os

# %%
cvd_19 = pd.read_csv("/Users/barborostasdemir/Desktop/Covid-19 Review Project/metadata.csv",nrows=100)
cvd_19.head(5)
# Out:
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4  9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
#
#                                                title                    doi  \
# 0  Clinical features of culture-proven Mycoplasma...  10.1186/1471-2334-1-6
# 1  Nitric oxide: a pro-inflammatory mediator in l...           10.1186/rr14
# 2    Surfactant protein-D and pulmonary host defense           10.1186/rr19
# 3               Role of endothelin-1 in lung disease           10.1186/rr44
# 4  Gene expression in epithelial cells in respons...           10.1186/rr61
#
#       pmcid  pubmed_id license  \
# 0  PMC35282   11472636   no-cc
# 1  PMC59543   11667967   no-cc
# ...

# %%
cvd_19.shape
# Out:
# (100, 19)

# %%
cvd_19.head()
# Out:
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4  9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
#
#                                                title                    doi  \
# 0  Clinical features of culture-proven Mycoplasma...  10.1186/1471-2334-1-6
# 1  Nitric oxide: a pro-inflammatory mediator in l...           10.1186/rr14
# 2    Surfactant protein-D and pulmonary host defense           10.1186/rr19
# 3               Role of endothelin-1 in lung disease           10.1186/rr44
# 4  Gene expression in epithelial cells in respons...           10.1186/rr61
#
#       pmcid  pubmed_id license  \
# 0  PMC35282   11472636   no-cc
# 1  PMC59543   11667967   no-cc
# ...

# %%
cvd_19.isna().sum()
# Out:
# cord_uid              0
# sha                   6
# source_x              0
# title                 0
# doi                   0
# pmcid                 0
# pubmed_id             0
# license               0
# abstract              8
# publish_time          0
# authors               6
# journal               0
# mag_id              100
# who_covidence_id    100
# arxiv_id            100
# pdf_json_files        6
# pmc_json_files        9
# url                   0
# s2_id               100
# dtype: int64

# %%
#we can leave this value empty because it affects 100 values.
cvd_19.drop(['mag_id','who_covidence_id','arxiv_id','s2_id'],axis =1,inplace = True)

# %%
cvd_19.head()
# Out:
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4  9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
#
#                                                title                    doi  \
# 0  Clinical features of culture-proven Mycoplasma...  10.1186/1471-2334-1-6
# 1  Nitric oxide: a pro-inflammatory mediator in l...           10.1186/rr14
# 2    Surfactant protein-D and pulmonary host defense           10.1186/rr19
# 3               Role of endothelin-1 in lung disease           10.1186/rr44
# 4  Gene expression in epithelial cells in respons...           10.1186/rr61
#
#       pmcid  pubmed_id license  \
# 0  PMC35282   11472636   no-cc
# 1  PMC59543   11667967   no-cc
# ...

# %%
cvd_19.isna().sum()
# Out:
# cord_uid          0
# sha               6
# source_x          0
# title             0
# doi               0
# pmcid             0
# pubmed_id         0
# license           0
# abstract          8
# publish_time      0
# authors           6
# journal           0
# pdf_json_files    6
# pmc_json_files    9
# url               0
# dtype: int64

# %%
cvd_19.groupby(['journal']).size().groupby(level=0).max()
# Out:
# journal
# AIDS Res Ther                                               1
# Ann Clin Microbiol Antimicrob                               1
# Aust New Zealand Health Policy                              2
# BMC Bioinformatics                                          2
# BMC Biotechnol                                              1
# BMC Gastroenterol                                           1
# BMC Genomics                                                2
# BMC Infect Dis                                              2
# BMC Med Ethics                                              2
# BMC Mol Biol                                                1
# BMC Public Health                                           8
# Biol Proced Online                                          1
# Cell Microbiol                                              1
# Clinical Chemistry                                          1
# Crit Care                                                   6
# ...

# %%
cvd_19.groupby(['license']).size().groupby(level=0).max()
# Out:
# license
# bronze-oa     3
# cc-by        46
# cc-by-nc      7
# cc0           2
# green-oa      4
# no-cc        38
# dtype: int64

# %%
cvd_19.groupby(['license','journal']).size()
# Out:
# license    journal
# bronze-oa  Clinical Chemistry                                         1
#            Journal of Neuropathology and Experimental Neurology       1
#            Journal of the American Medical Informatics Association    1
# cc-by      AIDS Res Ther                                              1
#            Ann Clin Microbiol Antimicrob                              1
#            Aust New Zealand Health Policy                             2
#            BMC Bioinformatics                                         2
#            BMC Biotechnol                                             1
#            BMC Gastroenterol                                          1
#            BMC Genomics                                               2
#            BMC Infect Dis                                             1
#            BMC Med Ethics                                             2
#            BMC Mol Biol                                               1
# ...

# %%
cvd_19.groupby(['publish_time']).size().groupby(level=0).max()
# Out:
# publish_time
# 1997-03-03    1
# 2000-04-17    1
# 2000-08-01    1
# 2000-08-15    1
# 2000-08-25    1
#              ..
# 2007-05-29    1
# 2007-05-30    1
# 2007-06-04    1
# 2007-06-06    1
# 2007-06-11    1
# Length: 88, dtype: int64

# %%
cvd_19.dtypes
# Out:
# cord_uid          object
# sha               object
# source_x          object
# title             object
# doi               object
# pmcid             object
# pubmed_id          int64
# license           object
# abstract          object
# publish_time      object
# authors           object
# journal           object
# pdf_json_files    object
# pmc_json_files    object
# url               object
# dtype: object

# %%
cvd_19['publish_time'] = pd.to_datetime(cvd_19['publish_time'], format='%Y-%m-%d')

# %%
cvd_19.dtypes
# Out:
# cord_uid                  object
# sha                       object
# source_x                  object
# title                     object
# doi                       object
# pmcid                     object
# pubmed_id                  int64
# license                   object
# abstract                  object
# publish_time      datetime64[ns]
# authors                   object
# journal                   object
# pdf_json_files            object
# pmc_json_files            object
# url                       object
# dtype: object

# %%
cvd_19['year'] = cvd_19['publish_time'].dt.year

# %%
cvd_19.head()
# Out:
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4  9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
#
#                                                title                    doi  \
# 0  Clinical features of culture-proven Mycoplasma...  10.1186/1471-2334-1-6
# 1  Nitric oxide: a pro-inflammatory mediator in l...           10.1186/rr14
# 2    Surfactant protein-D and pulmonary host defense           10.1186/rr19
# 3               Role of endothelin-1 in lung disease           10.1186/rr44
# 4  Gene expression in epithelial cells in respons...           10.1186/rr61
#
#       pmcid  pubmed_id license  \
# 0  PMC35282   11472636   no-cc
# 1  PMC59543   11667967   no-cc
# ...

# %%
cvd_19.groupby(['year']).size().groupby(level=0).max()
# Out:
# year
# 1997     1
# 2000     5
# 2001     7
# 2002     1
# 2003     4
# 2004    10
# 2005    23
# 2006    36
# 2007    13
# dtype: int64

# %%
cvd_19.groupby(['year','journal'])['title'].size()
# Out:
# year  journal
# 1997  EMBO J               1
# 2000  EMBO J               1
#       Respir Res           2
#       The EMBO Journal     2
# 2001  BMC Infect Dis       1
#                           ..
# 2007  Cell Microbiol       1
#       Nucleic Acids Res    1
#       PLoS One             5
#       PLoS Pathog          1
#       Virol J              1
# Name: title, Length: 69, dtype: int64

# %%
cvd_19.groupby(['year','journal']).size()
# Out:
# year  journal
# 1997  EMBO J               1
# 2000  EMBO J               1
#       Respir Res           2
#       The EMBO Journal     2
# 2001  BMC Infect Dis       1
#                           ..
# 2007  Cell Microbiol       1
#       Nucleic Acids Res    1
#       PLoS One             5
#       PLoS Pathog          1
#       Virol J              1
# Length: 69, dtype: int64

# %%
cvd_19.groupby(['year','license']).size()
# Out:
# year  license
# 1997  no-cc         1
# 2000  green-oa      2
#       no-cc         3
# 2001  green-oa      1
#       no-cc         6
# 2002  no-cc         1
# 2003  bronze-oa     1
#       no-cc         3
# 2004  bronze-oa     1
#       cc-by         3
#       no-cc         6
# 2005  cc-by        11
#       green-oa      1
#       no-cc        11
# 2006  bronze-oa     1
#       cc-by        23
#       cc-by-nc      6
#       no-cc         6
# 2007  cc-by         9
#       cc-by-nc      1
#       cc0           2
#       no-cc         1
# dtype: int64

# %%
metadata1 = cvd_19[['title','abstract']]
metadata1.head()
# Out:
#                                                title  \
# 0  Clinical features of culture-proven Mycoplasma...
# 1  Nitric oxide: a pro-inflammatory mediator in l...
# 2    Surfactant protein-D and pulmonary host defense
# 3               Role of endothelin-1 in lung disease
# 4  Gene expression in epithelial cells in respons...
#
#                                             abstract
# 0  OBJECTIVE: This retrospective chart review des...
# 1  Inflammatory diseases of the respiratory tract...
# 2  Surfactant protein-D (SP-D) participates in th...
# 3  Endothelin-1 (ET-1) is a 21 amino acid peptide...
# 4  Respiratory syncytial virus (RSV) and pneumoni...

# %%
metadata1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     100 non-null    object
#  1   abstract  92 non-null     object
# dtypes: object(2)
# memory usage: 1.7+ KB

# %%
metadata1.dropna(how="any",axis=0,inplace=True)
metadata1.reset_index(drop=True,inplace=True)
metadata1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     92 non-null     object
#  1   abstract  92 non-null     object
# dtypes: object(2)
# memory usage: 1.6+ KB
# /var/folders/tn/0kn0h9c50d12x3sx_v0jg89w0000gn/T/ipykernel_2895/3905292310.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata1.dropna(how="any",axis=0,inplace=True)

# %%
metadata1['text'] = metadata1['title'] + metadata1['abstract']
metadata1
# Out:
# /var/folders/tn/0kn0h9c50d12x3sx_v0jg89w0000gn/T/ipykernel_2895/4285303817.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata1['text'] = metadata1['title'] + metadata1['abstract']
#                                                 title  \
# 0   Clinical features of culture-proven Mycoplasma...
# 1   Nitric oxide: a pro-inflammatory mediator in l...
# 2     Surfactant protein-D and pulmonary host defense
# 3                Role of endothelin-1 in lung disease
# 4   Gene expression in epithelial cells in respons...
# ..                                                ...
# 87  Global Surveillance of Emerging Influenza Viru...
# 88  Transmission Parameters of the 2001 Foot and M...
# ...

# %%
metadata1['text'] = metadata1['text'].astype(str).str.lower()
metadata1.head()
# Out:
# /var/folders/tn/0kn0h9c50d12x3sx_v0jg89w0000gn/T/ipykernel_2895/320398156.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata1['text'] = metadata1['text'].astype(str).str.lower()
#                                                title  \
# 0  Clinical features of culture-proven Mycoplasma...
# 1  Nitric oxide: a pro-inflammatory mediator in l...
# 2    Surfactant protein-D and pulmonary host defense
# 3               Role of endothelin-1 in lung disease
# 4  Gene expression in epithelial cells in respons...
#
#                                             abstract  \
# 0  OBJECTIVE: This retrospective chart review des...
# 1  Inflammatory diseases of the respiratory tract...
# 2  Surfactant protein-D (SP-D) participates in th...
# ...
